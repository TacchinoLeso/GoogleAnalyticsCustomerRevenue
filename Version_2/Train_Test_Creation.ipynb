# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Random seed for reproducibility
seed = 202
np.random.seed(seed)

# Ignore warnings
import warnings
warnings.simplefilter('ignore')

# Garbage collector
import gc
gc.enable()

# %%
# Import the preprocessed dataframes
train_raw_df = pd.read_csv("preprocessed_train_v2(3).csv",
    dtype={'fullVisitorId': str}, nrows=None)
test_raw_df = pd.read_csv("preprocessed_test_v2(3).csv",
    dtype={'fullVisitorId': str}, nrows=None)
train_raw_df.shape, test_raw_df.shape
# Out:
# ((1708337, 39), (401589, 39))

# %%
train_raw_df.head()
# Out:
#   channelGrouping                              customDimensions      date  \
# 0  organic search             [{'index': '4', 'value': 'emea'}]  20171016
# 1        referral    [{'index': '4', 'value': 'north america'}]  20171016
# 2          direct    [{'index': '4', 'value': 'north america'}]  20171016
# 3  organic search             [{'index': '4', 'value': 'emea'}]  20171016
# 4  organic search  [{'index': '4', 'value': 'central america'}]  20171016
#
#          fullVisitorId     visitId  visitNumber  visitStartTime  \
# 0  3162355547410993243  1508198450            1      1508198450
# 1  8934116514970143966  1508176307            6      1508176307
# 2  7992466427990357681  1508201613            1      1508201613
# 3  9075655783635761930  1508169851            1      1508169851
# 4  6960673291025684308  1508190552            1      1508190552
#
#   device_browser device_deviceCategory  device_isMobile          ...           \
# 0        firefox               desktop            False          ...
# 1         chrome               desktop            False          ...
# 2         chrome                mobile             True          ...
# 3         chrome               desktop            False          ...
# 4         chrome               desktop            False          ...
#
#   trafficSource_adwordsClickInfo.gclId  \
# 0                              unknown
# 1                              unknown
# 2                              unknown
# 3                              unknown
# 4                              unknown
#
#   trafficSource_adwordsClickInfo.isVideoAd  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
#
#   trafficSource_adwordsClickInfo.page trafficSource_adwordsClickInfo.slot  \
# 0                                 0.0                             unknown
# 1                                 0.0                             unknown
# 2                                 0.0                             unknown
# 3                                 0.0                             unknown
# 4                                 0.0                             unknown
#
#   trafficSource_campaign trafficSource_isTrueDirect trafficSource_keyword  \
# 0                unknown                      False          water bottle
# 1                unknown                      False               unknown
# 2                unknown                       True               unknown
# 3                unknown                      False               unknown
# 4                unknown                      False               unknown
#
#   trafficSource_medium                         trafficSource_referralPath  \
# 0              organic                                            unknown
# 1             referral  /a/google.com/transportation/mtv-services/bike...
# 2              unknown                                            unknown
# 3              organic                                            unknown
# 4              organic                                            unknown
#
#    trafficSource_source
# 0                google
# 1      sites.google.com
# 2              (direct)
# 3                google
# 4                google
#
# [5 rows x 39 columns]

# %%
temp = train_raw_df['date'].dt.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c0705396dfc9> in <module>
#       1
# ----> 2 temp = train_raw_df['date'].dt.date
#
# c:\users\eugen\anaconda3\envs\tacchinoleso\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# c:\users\eugen\anaconda3\envs\tacchinoleso\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# c:\users\eugen\anaconda3\envs\tacchinoleso\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     323             pass  # we raise an attribute error anyway
#     324
# --> 325         raise AttributeError("Can only use .dt accessor with datetimelike "
#     326                              "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values
