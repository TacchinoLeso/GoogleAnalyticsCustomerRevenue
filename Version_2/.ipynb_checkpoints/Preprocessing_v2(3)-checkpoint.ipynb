# %%
import pandas as pd
import numpy as np

# Seaborn and matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# Random seed for reproducibility
seed = 202
np.random.seed(seed)

# Ignore warnings
import warnings
warnings.simplefilter('ignore')

# Garbage collector
import gc
gc.enable()

# %%
# Import the dataframes without JSON features and useless features
train_raw_df = pd.read_csv("cleaned_train_v2(2).csv",
    dtype={'fullVisitorId': str}, nrows=None)
test_raw_df = pd.read_csv("cleaned_test_v2(2).csv",
    dtype={'fullVisitorId': str}, nrows=None)
train_raw_df.shape, test_raw_df.shape
# Out:
# ((1708337, 38), (401589, 38))

# %% [markdown]
# ## First preprocessing

# %% [markdown]
# ### NOTE: the next step is optional

# %% [markdown]
# ### Inspect disguised nans

# %%
# check how many categories are present per column (before nans substitution)
for c in train_raw_df.columns:
    print(c, len(np.unique(train_raw_df[c].astype(str))))

# %%
from collections import Counter
Counter(train_raw_df['totals_sessionQualityDim'])

# %%
"""

POSSIBLE DATA HANDLING

device_browser:
    'Safari (in-app)' -> 'Safari'
    'Opera Mini' -> 'Opera'
    'Mozilla' -> 'Firefox'
    'Mozilla Compatible Agent' -> 'Firefox'
"""

# %%
train_raw_df['totals_timeOnSite'].unique()

# %% [markdown]
# ### Convert disguised nans

# %%
nan_list = [
    "(not set)",
    "not available in demo dataset",
    "not.configured",
    "(not provided)",
    "unknown.unknown",
    "/",
    "(Other)",
    "(other)",
    "(none)",
    "nan",
    "[]"
]

nan_dict = {nl:np.nan for nl in nan_list}

# convert all "disguised" missing values to nans
def miss_to_nan(df):
    df.replace(nan_dict, inplace=True) # convert disguised NaNs
    df.dropna(axis=1, how='all', inplace=True)
    return df

# %%
# apply the preprocessing up to this point and save into copies
train_df = miss_to_nan(train_raw_df)
test_df = miss_to_nan(test_raw_df)

# %%
train_df.isnull().sum()
# Out:
# channelGrouping                                     137
# customDimensions                                 333235
# fullVisitorId                                         0
# visitId                                               0
# visitNumber                                           0
# visitStartTime                                        0
# device_browser                                       12
# device_deviceCategory                                 0
# device_isMobile                                       0
# device_operatingSystem                            11815
# geoNetwork_city                                  998826
# geoNetwork_continent                               2517
# geoNetwork_country                                 2517
# geoNetwork_metro                                1319855
# geoNetwork_networkDomain                         769043
# geoNetwork_region                                982733
# geoNetwork_subContinent                            2517
# totals_bounces                                   836759
# totals_hits                                           0
# totals_newVisits                                 400907
# totals_pageviews                                    239
# totals_sessionQualityDim                         835274
# totals_timeOnSite                                874294
# totals_totalTransactionRevenue                  1689823
# totals_transactionRevenue                       1689823
# totals_transactions                             1689778
# trafficSource_adContent                         1643600
# trafficSource_adwordsClickInfo.adNetworkType    1633063
# trafficSource_adwordsClickInfo.gclId            1632914
# trafficSource_adwordsClickInfo.isVideoAd        1633063
# trafficSource_adwordsClickInfo.page             1633063
# trafficSource_adwordsClickInfo.slot             1633063
# trafficSource_campaign                          1604526
# trafficSource_isTrueDirect                      1173819
# trafficSource_keyword                           1621713
# trafficSource_medium                             566091
# trafficSource_referralPath                      1280366
# trafficSource_source                                 70
# dtype: int64

# %% [markdown]
# ### NOTE: the next step is optional

# %% [markdown]
# ### Inspect data

# %%
# check the nan condition in totals.newVisits
from itertools import compress
sum(list(compress(train_df['visitNumber'] > 1, train_df['totals.newVisits'].isnull()))) == train_df['totals.newVisits'].isnull().sum()

# %%
# check the nan condition in totals.newVisits
print(sum(train_df['totals.newVisits'].isnull()))
sum(list(compress(train_df['totals.newVisits'].isnull(), train_df['visitNumber'] > 1)))

# %%
# check if there is difference between nan and (none) in df['trafficSource.medium']
print(sum(train_df['trafficSource.medium'].isnull()))
sum(list(compress(train_df['trafficSource.medium'].isnull(), train_df['totals.transactionRevenue'] == 0)))

### c'è un valore con revenue !!!!!

# %%
#same shit for trafficSource.source
print(sum(train_df['trafficSource.source'].isnull()))
sum(list(compress(train_df['trafficSource.source'].isnull(), train_df['totals.transactionRevenue'] == 0)))

# %%
train_df.isnull().sum()

# %%
#check again number of categories in each variable (eg column)
for c in train_df.columns:
    print(c, len(np.unique(train_df[c].astype(str))))

# %%
for i in train_df.columns:    
    if len(train_df[i].unique()) <= 100:
        print(i + '\n')
        print(train_df[i].unique())
        print('\n')

# %% [markdown]
# ## Second preprocessing

# %% [markdown]
# ### NOTE: the next step is optional

# %%
train_df.columns

# %%
def train_test_distribution(col, dtype='float64'):
    """Plot a single numerical column distribution in linear and log scale."""
    fig, axis = plt.subplots(1, 2, figsize=(14,6))
    axis[0].set_title("Linear scale")
    axis[1].set_title("Log scale")
    
    train_df[col], test_df[col] = train_df[col].astype(dtype), test_df[col].astype(dtype)
    ax1 = sns.kdeplot(train_df[col].dropna(), label='train', ax=axis[0])
    ax2 = sns.kdeplot(test_df[col].dropna(), label='test', ax=axis[0])
    ax3 = sns.kdeplot(np.log(train_df[col].dropna()), label='train', ax=axis[1])
    ax4 = sns.kdeplot(np.log(test_df[col].dropna()), label='test', ax=axis[1])

# %%
train_test_distribution('totals_transactionRevenue')

# %% [markdown]
# ### Missing values filling

# %%
def fill_nans(df):
    
    
    df['channelGrouping'].fillna('Organic Search', inplace=True) # few nans, a lot of "Organic Search"
    df['device_browser'].fillna('Chrome', inplace=True) # few nans, a lot of "Chrome"
    df['device_operatingSystem'].fillna('unknown', inplace=True) # no predominance of any value, quite a bit of nans, keep separated category
    df['totals_pageviews'].fillna(1, inplace=True) # many 1s, nans do not bring any revenue -> nans become 1s
    df['trafficSource_medium'].fillna('unknown', inplace=True) # seems to be the same
    df['trafficSource_source'].fillna('unknown', inplace = True) # seems to be the same
    df['customDimensions'].fillna('unknown', inplace = True)
    
    
    df['geoNetwork_continent'].fillna('unknown', inplace=True)# keep separate category
    df['geoNetwork_country'].fillna('unknown', inplace=True)# keep separate category
    df['geoNetwork_subContinent'].fillna('unknown', inplace=True)# keep separate category

    # Targets
    df['totals_transactionRevenue'].fillna(0, inplace=True)
    df['totals_transactions'].fillna(0, inplace=True)
    df['totals_totalTransactionRevenue'].fillna(0, inplace=True)
    
    
    # Features with huge amout of nans
    df['totals_timeOnSite'].fillna(0, inplace=True) # to be decided together
    df['totals_sessionQualityDim'].fillna(0, inplace=True) # 1 means bad quality, and is the most frequent value. Anyway putting 0 may be significative
    df['geoNetwork_city'].fillna('unknown', inplace=True)
    df['geoNetwork_metro'].fillna('unknown', inplace=True)
    df['geoNetwork_networkDomain'].fillna('unknown', inplace=True)
    df['geoNetwork_region'].fillna('unknown', inplace=True)
    df['totals_bounces'].fillna(0, inplace=True) # nan and 1
    df['trafficSource_adContent'].fillna('unknown', inplace=True)
    df['trafficSource_adwordsClickInfo.adNetworkType'].fillna('unknown', inplace=True)
    df['trafficSource_adwordsClickInfo.gclId'].fillna('unknown', inplace=True)
    df['trafficSource_adwordsClickInfo.isVideoAd'].fillna(True, inplace=True) # nan and False
    df['trafficSource_adwordsClickInfo.page'].fillna(0, inplace=True) # 0 is not cointained in the set
    df['trafficSource_adwordsClickInfo.slot'].fillna('unknown', inplace=True)
    df['trafficSource_campaign'].fillna('unknown', inplace=True)
    df['trafficSource_isTrueDirect'].fillna(False, inplace=True) # nan and True
    df['trafficSource_keyword'].fillna('unknown', inplace=True)
    df['trafficSource_referralPath'].fillna('unknown', inplace=True)
    df['totals_newVisits'].fillna(0, inplace=True)# totals.newVisits is always == nan when visitNumber > 1, we keep it for now but it will be dropped eventually

    return df

# %%
train_df = fill_nans(train_df)
test_df = fill_nans(test_df)

# %%
train_df.isnull().sum()
# Out:
# channelGrouping                                 0
# customDimensions                                0
# fullVisitorId                                   0
# visitId                                         0
# visitNumber                                     0
# visitStartTime                                  0
# device_browser                                  0
# device_deviceCategory                           0
# device_isMobile                                 0
# device_operatingSystem                          0
# geoNetwork_city                                 0
# geoNetwork_continent                            0
# geoNetwork_country                              0
# geoNetwork_metro                                0
# geoNetwork_networkDomain                        0
# geoNetwork_region                               0
# geoNetwork_subContinent                         0
# totals_bounces                                  0
# totals_hits                                     0
# totals_newVisits                                0
# totals_pageviews                                0
# totals_sessionQualityDim                        0
# totals_timeOnSite                               0
# totals_totalTransactionRevenue                  0
# totals_transactionRevenue                       0
# totals_transactions                             0
# trafficSource_adContent                         0
# trafficSource_adwordsClickInfo.adNetworkType    0
# trafficSource_adwordsClickInfo.gclId            0
# trafficSource_adwordsClickInfo.isVideoAd        0
# trafficSource_adwordsClickInfo.page             0
# trafficSource_adwordsClickInfo.slot             0
# trafficSource_campaign                          0
# trafficSource_isTrueDirect                      0
# trafficSource_keyword                           0
# trafficSource_medium                            0
# trafficSource_referralPath                      0
# trafficSource_source                            0
# dtype: int64

# %% [markdown]
# ### Cast numerical features to float

# %%
# float_features = ['visitId', 'visitNumber', 'visitStartTime', 'totals.bounces', 'totals.hits',
#                  'totals.newVisits', 'totals.pageviews', 'trafficSource.adwordsClickInfo.page',
#                  'trafficSource.isTrueDirect']

# for col in float_features:
#     train_df[col] = train_df[col].astype(float)
#     test_df[col] = test_df[col].astype(float)

# %% [markdown]
# ### Cast string categorical features to lower case

# %%
# string_features = ['channelGrouping', 'customDimensions', 'device_browser', 'device_deviceCategory',
#                   'device_operatingSystem', 'geoNetwork_city', 'geoNetwork_continent', 'geoNetwork_country',
#                   'geoNetwork_metro', 'geoNetwork_networkDomain', 'geoNetwork_region', 'geoNetwork_subContinent',
#                   'trafficSource_adContent', 'trafficSource_adwordsClickInfo.adNetworkType', 'trafficSource_adwordsClickInfo.gclId',
#                   'trafficSource_adwordsClickInfo.slot', 'trafficSource_campaign', 'trafficSource_referralPath',
#                   'trafficSource_medium', 'trafficSource_source', 'trafficSource_keyword']

# for col in string_features:
#     train_df[col] = train_df[col].str.lower().astype(str)
#     train_df[col] = train_df[col].astype(str)
#     test_df[col] = test_df[col].str.lower().astype(str)
#     test_df[col] = test_df[col].astype(str)

# %% [markdown]
# ### NOTE: the next step is optional (may improve performances but it has to be tested)

# %% [markdown]
# ### Cleaning rare categories

# %%
# Actually we have no longer missing values, and we can manage the problem of the rare categories
# We group them in an overfeature
def clear_rare_categories(df, feature, limit = 900):

    vc = df[feature].value_counts()
    
    common = vc > limit
    common = set(common.index[common].values)
    print("Set", sum(vc <= limit), feature, "categories to 'other';", end=" ")
    
    df.loc[df[feature].map(lambda x: x not in common), feature] = 'other'
    print("now there are", df[feature].nunique(), "categories")
    
    return df

raw_string_features = [
    "channelGrouping",
    "device_browser",
    "device_deviceCategory",
    "device_operatingSystem",
    "geoNetwork_city",
    "geoNetwork_continent",
    "geoNetwork_country",
    "geoNetwork_metro",
    "geoNetwork_networkDomain",
    "geoNetwork_region",
    "geoNetwork_subContinent",
    "trafficSource_adContent",
    "trafficSource_adwordsClickInfo.adNetworkType",
    "trafficSource_adwordsClickInfo.slot",
    "trafficSource_campaign",
    "trafficSource_keyword",
    "trafficSource_medium",
    "trafficSource_referralPath",
    "trafficSource_source",
    "customDimensions",
    "trafficSource_adwordsClickInfo.gclId"
]

#check
for i in train_df.columns:
    if(i not in raw_string_features):
        print(i)
# Out:
# fullVisitorId
# visitId
# visitNumber
# visitStartTime
# device_isMobile
# totals_bounces
# totals_hits
# totals_newVisits
# totals_pageviews
# totals_sessionQualityDim
# totals_timeOnSite
# totals_totalTransactionRevenue
# totals_transactionRevenue
# totals_transactions
# trafficSource_adwordsClickInfo.isVideoAd
# trafficSource_adwordsClickInfo.page
# trafficSource_isTrueDirect

# %%
for feat in raw_string_features:
    print("\nTRAIN:\n")
    train_df = clear_rare_categories(train_df, feat)
    print("\nTEST:\n")
    test_df = clear_rare_categories(test_df, feat)
# Out:
# TRAIN:
#
# Set 0 channelGrouping categories to 'other'; now there are 7 categories
#
# TEST:
#
# Set 0 channelGrouping categories to 'other'; now there are 7 categories
#
# TRAIN:
#
# Set 113 device_browser categories to 'other'; now there are 16 categories
#
# TEST:
#
# Set 52 device_browser categories to 'other'; now there are 11 categories
#
# TRAIN:
#
# Set 0 device_deviceCategory categories to 'other'; now there are 3 categories
#
# TEST:
#
# Set 0 device_deviceCategory categories to 'other'; now there are 3 categories
#
# TRAIN:
#
# Set 15 device_operatingSystem categories to 'other'; now there are 10 categories
#
# TEST:
#
# Set 15 device_operatingSystem categories to 'other'; now there are 8 categories
#
# TRAIN:
#
# Set 849 geoNetwork_city categories to 'other'; now there are 107 categories
#
# TEST:
#
# Set 459 geoNetwork_city categories to 'other'; now there are 44 categories
#
# TRAIN:
#
# Set 0 geoNetwork_continent categories to 'other'; now there are 6 categories
#
# TEST:
#
# Set 1 geoNetwork_continent categories to 'other'; now there are 6 categories
#
# TRAIN:
#
# Set 146 geoNetwork_country categories to 'other'; now there are 83 categories
#
# TEST:
#
# Set 160 geoNetwork_country categories to 'other'; now there are 49 categories
#
# TRAIN:
#
# Set 96 geoNetwork_metro categories to 'other'; now there are 27 categories
#
# TEST:
#
# Set 65 geoNetwork_metro categories to 'other'; now there are 17 categories
#
# TRAIN:
#
# Set 41833 geoNetwork_networkDomain categories to 'other'; now there are 148 categories
#
# TEST:
#
# Set 15905 geoNetwork_networkDomain categories to 'other'; now there are 28 categories
#
# TRAIN:
#
# Set 388 geoNetwork_region categories to 'other'; now there are 95 categories
#
# TEST:
#
# Set 231 geoNetwork_region categories to 'other'; now there are 38 categories
#
# TRAIN:
#
# Set 3 geoNetwork_subContinent categories to 'other'; now there are 21 categories
#
# TEST:
#
# Set 7 geoNetwork_subContinent categories to 'other'; now there are 17 categories
#
# TRAIN:
#
# Set 70 trafficSource_adContent categories to 'other'; now there are 8 categories
#
# TEST:
#
# Set 25 trafficSource_adContent categories to 'other'; now there are 4 categories
#
# TRAIN:
#
# Set 1 trafficSource_adwordsClickInfo.adNetworkType categories to 'other'; now there are 4 categories
#
# TEST:
#
# Set 1 trafficSource_adwordsClickInfo.adNetworkType categories to 'other'; now there are 3 categories
#
# TRAIN:
#
# Set 1 trafficSource_adwordsClickInfo.slot categories to 'other'; now there are 4 categories
#
# TEST:
#
# Set 4 trafficSource_adwordsClickInfo.slot categories to 'other'; now there are 3 categories
#
# TRAIN:
#
# Set 25 trafficSource_campaign categories to 'other'; now there are 9 categories
#
# TEST:
#
# Set 19 trafficSource_campaign categories to 'other'; now there are 8 categories
#
# TRAIN:
#
# Set 4536 trafficSource_keyword categories to 'other'; now there are 11 categories
#
# TEST:
#
# Set 672 trafficSource_keyword categories to 'other'; now there are 5 categories
#
# TRAIN:
#
# Set 0 trafficSource_medium categories to 'other'; now there are 6 categories
#
# TEST:
#
# Set 0 trafficSource_medium categories to 'other'; now there are 6 categories
#
# TRAIN:
#
# Set 3139 trafficSource_referralPath categories to 'other'; now there are 58 categories
#
# TEST:
#
# Set 1742 trafficSource_referralPath categories to 'other'; now there are 13 categories
#
# TRAIN:
#
# Set 322 trafficSource_source categories to 'other'; now there are 24 categories
#
# TEST:
#
# Set 180 trafficSource_source categories to 'other'; now there are 13 categories
#
# TRAIN:
#
# Set 0 customDimensions categories to 'other'; now there are 6 categories
#
# TEST:
#
# Set 0 customDimensions categories to 'other'; now there are 6 categories
#
# TRAIN:
#
# Set 59008 trafficSource_adwordsClickInfo.gclId categories to 'other'; now there are 2 categories
#
# TEST:
#
# Set 9016 trafficSource_adwordsClickInfo.gclId categories to 'other'; now there are 2 categories

# %%
for i in train_df.columns:    
    if len(train_df[i].unique()) <= 100:
        print(i + '\n')
        print(train_df[i].unique())
        print('\n')
# Out:
# channelGrouping
#
# ['Organic Search' 'Referral' 'Direct' 'Paid Search' 'Display' 'Affiliates'
#  'Social']
#
#
# customDimensions
#
# ["[{'index': '4', 'value': 'EMEA'}]"
#  "[{'index': '4', 'value': 'North America'}]"
#  "[{'index': '4', 'value': 'Central America'}]" 'unknown'
#  "[{'index': '4', 'value': 'APAC'}]"
#  "[{'index': '4', 'value': 'South America'}]"]
#
#
# device_browser
#
# ['Firefox' 'Chrome' 'Safari' 'UC Browser' 'Internet Explorer' 'Edge'
#  'Samsung Internet' 'Android Webview' 'Safari (in-app)' 'Opera Mini'
#  'Opera' 'YaBrowser' 'Amazon Silk' 'other' 'Coc Coc' 'Android Browser']
#
#
# device_deviceCategory
#
# ['desktop' 'mobile' 'tablet']
#
#
# device_isMobile
#
# [False  True]
#
#
# device_operatingSystem
#
# ['Windows' 'Chrome OS' 'Android' 'Macintosh' 'iOS' 'Linux' 'unknown'
#  'Windows Phone' 'Samsung' 'other']
#
#
# geoNetwork_continent
#
# ['Europe' 'Americas' 'Asia' 'Oceania' 'unknown' 'Africa']
#
#
# geoNetwork_country
#
# ['Germany' 'United States' 'Turkey' 'Mexico' 'United Kingdom' 'Denmark'
#  'Netherlands' 'Sweden' 'Canada' 'India' 'Belgium' 'Philippines'
#  'Slovakia' 'Brazil' 'Japan' 'Taiwan' 'Peru' 'Ireland' 'Norway' 'Romania'
#  'Russia' 'Italy' 'New Zealand' 'Czechia' 'Serbia' 'Argentina' 'Australia'
#  'Hong Kong' 'Indonesia' 'Singapore' 'Kazakhstan' 'Thailand' 'Ecuador'
#  'Switzerland' 'Spain' 'France' 'Malaysia' 'Poland' 'Bulgaria' 'Jordan'
#  'China' 'Pakistan' 'unknown' 'Israel' 'Vietnam' 'Bangladesh' 'Greece'
#  'Algeria' 'Georgia' 'Ukraine' 'South Korea' 'Austria' 'other' 'Colombia'
#  'Egypt' 'United Arab Emirates' 'Portugal' 'Latvia' 'Chile' 'Belarus'
#  'South Africa' 'Nigeria' 'Venezuela' 'Sri Lanka' 'Estonia' 'Croatia'
#  'Lithuania' 'Puerto Rico' 'Saudi Arabia' 'Dominican Republic' 'Finland'
#  'Hungary' 'Cambodia' 'Tunisia' 'Morocco' 'Iraq' 'Guatemala' 'Slovenia'
#  'Kenya' 'Costa Rica' 'Bosnia & Herzegovina' 'Uruguay' 'Macedonia (FYROM)']
#
#
# geoNetwork_metro
#
# ['unknown' 'San Francisco-Oakland-San Jose CA' 'London' 'JP_KANTO'
#  'Los Angeles CA' 'Pittsburgh PA' 'Detroit MI' 'Boston MA-Manchester NH'
#  'New York NY' 'Seattle-Tacoma WA' 'Washington DC (Hagerstown MD)'
#  'San Antonio TX' 'Atlanta GA' 'Chicago IL' 'Dallas-Ft. Worth TX'
#  'Philadelphia PA' 'San Diego CA' 'Austin TX' 'other' 'Houston TX'
#  'Denver CO' 'Roanoke-Lynchburg VA' 'Charlotte NC' 'Portland OR'
#  'Phoenix AZ' 'North West' 'Orlando-Daytona Beach-Melbourne FL']
#
#
# geoNetwork_region
#
# ['unknown' 'California' 'England' 'Mexico City' 'Nevada' 'other' 'Tokyo'
#  'County Dublin' 'Maharashtra' 'Istanbul' 'Ontario' 'Telangana'
#  'Pennsylvania' 'Michigan' 'Massachusetts' 'British Columbia'
#  'Madhya Pradesh' 'Quebec' 'New South Wales' 'Jakarta' 'New York'
#  'State of Sao Paulo' 'Washington' 'District of Columbia' 'Delhi'
#  'Karnataka' 'Bangkok' 'Zurich' 'Masovian Voivodeship' 'Texas' 'Georgia'
#  'Illinois' 'Tamil Nadu' 'Lombardy' 'Federal Territory of Kuala Lumpur'
#  'Tennessee' 'Hanoi' 'Taipei City' 'Madrid' 'Berlin' 'Ho Chi Minh City'
#  'Victoria' 'Seoul' 'Ile-de-France' 'Lisbon' 'Bogota' 'New Taipei City'
#  'Stockholm County' 'Lagos' 'Riyadh Province' 'Dubai' 'Colorado'
#  'Buenos Aires' 'Lima Region' 'Santiago Metropolitan Region' 'Dublin City'
#  'North Holland' 'Virginia' 'Community of Madrid' 'West Bengal'
#  'Catalonia' 'State of Rio de Janeiro' 'Queensland' 'Moscow' 'Izmir'
#  'Lazio' 'Tel Aviv District' 'Ho Chi Minh' 'Ankara' 'Metro Manila'
#  'Wisconsin' 'Dhaka Division' 'North Carolina' 'Osaka Prefecture'
#  'Bavaria' 'Uttar Pradesh' 'Oregon' 'Kyiv city' 'Hamburg' 'Arizona'
#  'Rajasthan' 'Ohio' 'Attica' 'Gujarat' 'Vienna' 'Makkah Province'
#  'Alberta' 'Haryana' 'Bucharest' 'Hauts-de-France' 'Florida' 'New Jersey'
#  'Chandigarh' 'Cairo Governorate' 'Bihar']
#
#
# geoNetwork_subContinent
#
# ['Western Europe' 'Northern America' 'Western Asia' 'Central America'
#  'Northern Europe' 'Southern Asia' 'Southeast Asia' 'Eastern Europe'
#  'South America' 'Eastern Asia' 'Southern Europe' 'Australasia'
#  'Central Asia' 'unknown' 'Northern Africa' 'Eastern Africa'
#  'Southern Africa' 'Western Africa' 'Caribbean' 'Middle Africa' 'other']
#
#
# totals_bounces
#
# [1. 0.]
#
#
# totals_newVisits
#
# [1. 0.]
#
#
# totals_transactions
#
# [ 0.  1.  2.  3.  4.  8.  7.  5.  6. 10. 21. 25. 12. 15.]
#
#
# trafficSource_adContent
#
# ['unknown' 'other' 'Google Merchandise Store' 'Display Ad created 3/11/14'
#  'Google Online Store' 'Google Merchandise Collection'
#  'Smart display ad - 8/17/2017' 'Placement Accessores 300 x 250']
#
#
# trafficSource_adwordsClickInfo.adNetworkType
#
# ['unknown' 'Google Search' 'Content' 'other']
#
#
# trafficSource_adwordsClickInfo.gclId
#
# ['unknown' 'other']
#
#
# trafficSource_adwordsClickInfo.isVideoAd
#
# [ True False]
#
#
# trafficSource_adwordsClickInfo.page
#
# [ 0.  1.  3.  2.  5.  6.  4. 14.  7.  8.  9. 12.]
#
#
# trafficSource_adwordsClickInfo.slot
#
# ['unknown' 'Top' 'RHS' 'other']
#
#
# trafficSource_campaign
#
# ['unknown' 'other' 'AW - Dynamic Search Ads Whole Site'
#  '1000557 | GA | US | en | Hybrid | GDN Text+Banner | AS'
#  'Data Share Promo' '1000557 | GA | US | en | Hybrid | GDN Remarketing'
#  'AW - Accessories' 'Smart Display Campaign'
#  '"google + redesign/Accessories March 17" All Users Similar Audiences']
#
#
# trafficSource_isTrueDirect
#
# [False  True]
#
#
# trafficSource_keyword
#
# ['other' 'unknown' '(Remarketing/Content targeting)' '6qEhsCssdK0z36ri'
#  '(automatic matching)' '1hZbAqLCbjwfgOH7' '1X4Me6ZKNV0zg-jV'
#  '(User vertical targeting)' 'google store' 'Google Merchandise'
#  'google merchandise store']
#
#
# trafficSource_medium
#
# ['organic' 'referral' 'unknown' 'cpc' 'affiliate' 'cpm']
#
#
# trafficSource_referralPath
#
# ['unknown' 'other' '/offer/2145' '/analytics/web/' '/gopher'
#  '/permissions/using-the-logo.html' '/forum/'
#  '/YKEI_mrn/items/c10b14f9a69ff71b1b7a' '/yt/about/copyright/'
#  '/yt/about/' '/intl/ja/yt/about/' '/yt/about/press/' '/mobile'
#  '/r/golang/comments/4spnk9/where_to_buy_the_golang_gopher_plush/'
#  '/yt/dev/' '/yt/creators/' '/yt/advertise/' '/yt/about/brand-resources/'
#  '/intl/ru/yt/about/'
#  '/Where-can-I-buy-a-stuffed-Go-language-gopher-mascot-online'
#  '/pagead/ads' '/How-can-one-get-a-Google-T-shirt-in-India'
#  '/a/google.com/forum/' '/yt/jobs/' '/intl/es-419/yt/about/'
#  '/intl/pt-BR/yt/about/' '/intl/en-GB/yt/about/policies/'
#  '/yt/about/policies/'
#  '/a/google.com/googletopia/discounts-deals-and-free-stuff/alphabet-google-discounts'
#  '/mail/u/0/'
#  '/od/Things-To-Do-in-Silicon-Valley/fl/How-To-Visit-the-Googleplex-the-Google-Head-Office-in-Mountain-View.htm'
#  '/analytics/web/inpage_launch' '/yt/about/it/' '/yt/about/ja/'
#  '/yt/about/th/' '/yt/about/es/' '/yt/about/ru/' '/yt/about/vi/'
#  '/yt/about/pt-BR/' '/yt/about/es-419/' '/yt/about/iw/' '/yt/about/tr/'
#  '/yt/about/en-GB/' '/yt/about/de/' '/yt/about/pl/' '/yt/about/ar/'
#  '/yt/about/fr/' '/yt/about/zh-TW/' '/yt/about/id/' '/yt/about/ko/'
#  '/yt/about/zh-CN/' '/yt/about/ro/' '/analytics/app/'
#  '/yt/music/index.html' '/intl/en/yt/advertise/' '/moma'
#  '/intl/ar/yt/advertise/' '/safeframe/1-0-14/html/container.html']
#
#
# trafficSource_source
#
# ['google' 'sites.google.com' '(direct)' 'analytics.google.com'
#  'blog.golang.org' 'Partners' 'google.com' 'other' 'bing' 'qiita.com'
#  'youtube.com' 'reddit.com' 'quora.com' 'l.facebook.com'
#  'groups.google.com' 'baidu' 'm.facebook.com' 'yahoo' 'mail.google.com'
#  'dfa' 'siliconvalley.about.com' 'facebook.com'
#  'googleads.g.doubleclick.net' 't.co']

# %%
#check again number of categories in each variable (eg column)
for c in train_df.columns:
    print(c, len(np.unique(train_df[c].astype(str))))
# Out:
# channelGrouping 7
# customDimensions 6
# fullVisitorId 1323730
# visitId 1665802
# visitNumber 457
# visitStartTime 1667423
# device_browser 16
# device_deviceCategory 3
# device_isMobile 2
# device_operatingSystem 10
# geoNetwork_city 107
# geoNetwork_continent 6
# geoNetwork_country 83
# geoNetwork_metro 27
# geoNetwork_networkDomain 148
# geoNetwork_region 95
# geoNetwork_subContinent 21
# totals_bounces 2
# totals_hits 297
# totals_newVisits 2
# totals_pageviews 230
# totals_sessionQualityDim 101
# totals_timeOnSite 4775
# totals_totalTransactionRevenue 8507
# totals_transactionRevenue 7252
# totals_transactions 14
# trafficSource_adContent 8
# trafficSource_adwordsClickInfo.adNetworkType 4
# trafficSource_adwordsClickInfo.gclId 2
# trafficSource_adwordsClickInfo.isVideoAd 2
# trafficSource_adwordsClickInfo.page 12
# trafficSource_adwordsClickInfo.slot 4
# trafficSource_campaign 9
# trafficSource_isTrueDirect 2
# trafficSource_keyword 11
# trafficSource_medium 6
# trafficSource_referralPath 58
# trafficSource_source 24

# %% [markdown]
# ### Drop meaningless columns

# %%
meaningless_columns =["visitId"]

def drop_meaningless_columns(df, meaningless_columns):
    df.drop(meaningless_columns, axis=1, inplace=True)
    return df

train_df = drop_meaningless_columns(train_df, meaningless_columns)
test_df = drop_meaningless_columns(test_df, meaningless_columns)
train_df.shape, test_df.shape
# Out:
# ((1708337, 37), (401589, 37))

# %% [markdown]
# ### NOTE: the next step is optional

# %% [markdown]
# ###  Label encoder

# %%
from sklearn import preprocessing

for col in raw_string_features:
    print(col)
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(train_df[col].values.astype('str')) + list(test_df[col].values.astype('str')))
    train_df[col] = lbl.transform(list(train_df[col].values.astype('str')))
    test_df[col] = lbl.transform(list(test_df[col].values.astype('str')))
# Out:
# channelGrouping
# device_browser
# device_deviceCategory
# device_operatingSystem
# geoNetwork_city
# geoNetwork_continent
# geoNetwork_country
# geoNetwork_metro
# geoNetwork_networkDomain
# geoNetwork_region
# geoNetwork_subContinent
# trafficSource_adContent
# trafficSource_adwordsClickInfo.adNetworkType
# trafficSource_adwordsClickInfo.slot
# trafficSource_campaign
# trafficSource_keyword
# trafficSource_medium
# trafficSource_referralPath
# trafficSource_source
# customDimensions
# trafficSource_adwordsClickInfo.gclId

# %%
train_df.head()
# Out:
#    channelGrouping  customDimensions        fullVisitorId  visitNumber  \
# 0                3                 2  3162355547410993243            1
# 1                5                 3  8934116514970143966            6
# 2                1                 3  7992466427990357681            1
# 3                3                 2  9075655783635761930            1
# 4                3                 1  6960673291025684308            1
#
#    visitStartTime  device_browser  device_deviceCategory  device_isMobile  \
# 0      1508198450               6                      0            False
# 1      1508176307               3                      0            False
# 2      1508201613               3                      1             True
# 3      1508169851               3                      0            False
# 4      1508190552               3                      0            False
#
#    device_operatingSystem  geoNetwork_city          ...           \
# 0                       5              106          ...
# 1                       1               24          ...
# 2                       0              106          ...
# 3                       5              106          ...
# 4                       5              106          ...
#
#    trafficSource_adwordsClickInfo.gclId  \
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1
#
#    trafficSource_adwordsClickInfo.isVideoAd  \
# 0                                      True
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
#
#    trafficSource_adwordsClickInfo.page  trafficSource_adwordsClickInfo.slot  \
# 0                                  0.0                                    4
# 1                                  0.0                                    4
# 2                                  0.0                                    4
# 3                                  0.0                                    4
# 4                                  0.0                                    4
#
#    trafficSource_campaign  trafficSource_isTrueDirect  trafficSource_keyword  \
# 0                      13                       False                     11
# 1                      13                       False                     12
# 2                      13                        True                     12
# 3                      13                       False                     12
# 4                      13                       False                     12
#
#    trafficSource_medium  trafficSource_referralPath  trafficSource_source
# 0                     3                          58                     9
# 1                     4                          57                    21
# 2                     5                          58                     0
# 3                     3                          58                     9
# 4                     3                          58                     9
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Export Dataframes

# %%
train_df.to_csv('preprocessed_train_v2(3).csv', index = False)
test_df.to_csv('preprocessed_test_v2(3).csv', index = False)
