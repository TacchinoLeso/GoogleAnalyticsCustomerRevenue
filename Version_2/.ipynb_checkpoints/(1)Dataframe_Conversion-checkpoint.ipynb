# %% [markdown]
# # Data inspect and conversion from mixed to dataframe format

# %%
import os
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

# Random seed for reproducibility
seed = 202
np.random.seed(seed)

# Ignore warnings
import warnings
warnings.simplefilter('ignore')

# Garbage collector
import gc
gc.enable()

# %%
# With this function, we can directily import the whole dataframe according to
# the JSON format. One of the best JSON conversion technique
# https://www.kaggle.com/sudalairajkumar/simple-exploration-baseline-ga-customer-revenue
def load_df(csv_path='data.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}_{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
# %%time
train_df = load_df("train.csv")
test_df = load_df("test.csv")
# Out:
# Loaded train_v2.csv. Shape: (1708337, 60)
# Loaded test_v2.csv. Shape: (401589, 59)
# Wall time: 31min 10s

# %% [markdown]
# ### Drop hits column (unfeasible)

# %%
train_df.drop(['hits'], axis=1, inplace=True)
test_df.drop(['hits'], axis=1, inplace=True)

# %%
train_df.head()
# Out:
#   channelGrouping                              customDimensions      date  \
# 0  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral    [{'index': '4', 'value': 'North America'}]  20171016
# 2          Direct    [{'index': '4', 'value': 'North America'}]  20171016
# 3  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search  [{'index': '4', 'value': 'Central America'}]  20171016
#
#          fullVisitorId  socialEngagementType     visitId  visitNumber  \
# 0  3162355547410993243  Not Socially Engaged  1508198450            1
# 1  8934116514970143966  Not Socially Engaged  1508176307            6
# 2  7992466427990357681  Not Socially Engaged  1508201613            1
# 3  9075655783635761930  Not Socially Engaged  1508169851            1
# 4  6960673291025684308  Not Socially Engaged  1508190552            1
#
#    visitStartTime device_browser             device_browserSize  \
# 0      1508198450        Firefox  not available in demo dataset
# 1      1508176307         Chrome  not available in demo dataset
# 2      1508201613         Chrome  not available in demo dataset
# 3      1508169851         Chrome  not available in demo dataset
# 4      1508190552         Chrome  not available in demo dataset
#
#           ...          trafficSource_adwordsClickInfo.isVideoAd  \
# 0         ...                                               NaN
# 1         ...                                               NaN
# 2         ...                                               NaN
# 3         ...                                               NaN
# 4         ...                                               NaN
#
#   trafficSource_adwordsClickInfo.page trafficSource_adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    trafficSource_campaign trafficSource_campaignCode  \
# 0               (not set)                        NaN
# 1               (not set)                        NaN
# 2               (not set)                        NaN
# 3               (not set)                        NaN
# 4               (not set)                        NaN
#
#   trafficSource_isTrueDirect trafficSource_keyword trafficSource_medium  \
# 0                        NaN          water bottle              organic
# 1                        NaN                   NaN             referral
# 2                       True                   NaN               (none)
# 3                        NaN        (not provided)              organic
# 4                        NaN        (not provided)              organic
#
#                           trafficSource_referralPath trafficSource_source
# 0                                                NaN               google
# 1  /a/google.com/transportation/mtv-services/bike...     sites.google.com
# 2                                                NaN             (direct)
# 3                                                NaN               google
# 4                                                NaN               google
#
# [5 rows x 59 columns]

# %%
test_df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'APAC'}]  20180511
# 1          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 2  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
# 3          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 4  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
#
#          fullVisitorId  socialEngagementType     visitId  visitNumber  \
# 0  7460955084541987166  Not Socially Engaged  1526099341            2
# 1   460252456180441002  Not Socially Engaged  1526064483          166
# 2  3461808543879602873  Not Socially Engaged  1526067157            2
# 3   975129477712150630  Not Socially Engaged  1526107551            4
# 4  8381672768065729990  Not Socially Engaged  1526060254            1
#
#    visitStartTime     device_browser             device_browserSize  \
# 0      1526099341             Chrome  not available in demo dataset
# 1      1526064483             Chrome  not available in demo dataset
# 2      1526067157             Chrome  not available in demo dataset
# 3      1526107551             Chrome  not available in demo dataset
# 4      1526060254  Internet Explorer  not available in demo dataset
#
#           ...          trafficSource_adwordsClickInfo.gclId  \
# 0         ...                                           NaN
# 1         ...                                           NaN
# 2         ...                                           NaN
# 3         ...                                           NaN
# 4         ...                                           NaN
#
#   trafficSource_adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   trafficSource_adwordsClickInfo.page  trafficSource_adwordsClickInfo.slot  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   trafficSource_campaign trafficSource_isTrueDirect trafficSource_keyword  \
# 0              (not set)                       True        (not provided)
# 1              (not set)                       True             (not set)
# 2              (not set)                       True        (not provided)
# 3              (not set)                       True             (not set)
# 4              (not set)                        NaN        (not provided)
#
#   trafficSource_medium trafficSource_referralPath trafficSource_source
# 0              organic                  (not set)               google
# 1               (none)                  (not set)             (direct)
# 2              organic                  (not set)               google
# 3               (none)                  (not set)             (direct)
# 4              organic                  (not set)               google
#
# [5 rows x 58 columns]

# %% [markdown]
# ### Export Dataframes

# %%
train_df.to_csv('(1)dataframe_train.csv', index = False)
test_df.to_csv('(1)dataframe_test.csv', index = False)
